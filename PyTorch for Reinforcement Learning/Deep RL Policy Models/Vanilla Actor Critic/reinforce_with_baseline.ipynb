# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import gymnasium as gym
import matplotlib.pyplot as plt
import networkx as nx
from IPython.display import Video

# %% [markdown]
# ### Compute Returns
#
# Computing the returns from our trajectory is identical to before!

# %% [markdown]
# ### Train our Model
#
# This is mostly identical to before but we have a few changes:
#
# 1) We have two models that both have to be optimized, so we can also define two optimizers.
# 2) Instead of using $G_t$ directly, we will compute our advantage $A(s,a) = G_t - V(s)$

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import gymnasium as gym

class ActorNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(ActorNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(64, output_dim)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, state):
        x = self.fc1(state)
        x = self.relu(x)
        x = self.fc2(x)
        action_probs = self.softmax(x)
        return action_probs

class CriticNetwork(nn.Module):
    def __init__(self, input_dim):
        super(CriticNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(64, 1)

    def forward(self, state):
        x = self.fc1(state)
        x = self.relu(x)
        state_value = self.fc2(x)
        return state_value

class ActorCriticAgent:
    def __init__(self, env, actor_lr=0.001, critic_lr=0.005, gamma=0.99):
        self.env = env
        self.actor = ActorNetwork(env.observation_space.shape[0], env.action_space.n)
        self.critic = CriticNetwork(env.observation_space.shape[0])
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=actor_lr)
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=critic_lr)
        self.gamma = gamma

    def select_action(self, state):
         state = torch.FloatTensor(state).unsqueeze(0)
         probs = self.actor(state)
         action = np.random.choice(self.env.action_space.n, p=probs.detach().numpy()[0])
         return action

    def train_step(self, state, action, reward, next_state, done):
        state = torch.FloatTensor(state).unsqueeze(0)
        next_state = torch.FloatTensor(next_state).unsqueeze(0)

        # Critic update
        state_value = self.critic(state)
        next_state_value = self.critic(next_state)
        td_target = reward + self.gamma * next_state_value * (1 - done)
        critic_loss = nn.MSELoss()(state_value, td_target)

        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Actor update
        probs = self.actor(state)
        log_prob = torch.log(probs[0][action])
        advantage = td_target - state_value
        actor_loss = -log_prob * advantage.detach()

        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

# %%
env = gym.make('LunarLander-v3')
agent = ActorCriticAgent(env)

episodes = 200
for episode in range(episodes):
    state = env.reset()[0]
    done = False
    total_reward = 0

    while not done:
        action = agent.select_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        agent.train_step(state, action, reward, next_state, done)

        total_reward += reward
        state = next_state

    print(f"Episode: {episode + 1}, Total Reward: {total_reward}")

env.close()
# Out:
# Episode: 1, Total Reward: -49.657901693494395
# Episode: 2, Total Reward: -398.14078481707793
# Episode: 3, Total Reward: -395.348345029353
# Episode: 4, Total Reward: -300.6674100394823
# Episode: 5, Total Reward: -372.524935825173
# Episode: 6, Total Reward: -213.11099822602583
# Episode: 7, Total Reward: -82.12964535693312
# Episode: 8, Total Reward: -213.85316140456888
# Episode: 9, Total Reward: -166.88457185717914
# Episode: 10, Total Reward: -240.32921176830365
# Episode: 11, Total Reward: -464.78259080242725
# Episode: 12, Total Reward: -340.58690768639246
# Episode: 13, Total Reward: -78.00880697958297
# Episode: 14, Total Reward: -147.35743586501297
# Episode: 15, Total Reward: -438.6649297618385
# Episode: 16, Total Reward: -60.51617845660549
# Episode: 17, Total Reward: -315.0721493902753
# Episode: 18, Total Reward: -29.207307740710007
# Episode: 19, Total Reward: -252.18492559861417
# Episode: 20, Total Reward: -172.65279078818725
# Episode: 21, Total Reward: -252.13702887494765
# Episode: 22, Total Reward: -247.26929428919854
# Episode: 23, Total Reward: -317.06408381495606
# Episode: 24, Total Reward: -46.051581684887395
# Episode: 25, Total Reward: -84.65351508116026
# Episode: 26, Total Reward: -380.31412276313876
# Episode: 27, Total Reward: -299.6847680084819
# Episode: 28, Total Reward: -214.85315697121848
# Episode: 29, Total Reward: -378.78072658463253
# Episode: 30, Total Reward: 26.381284233075498
# Episode: 31, Total Reward: -158.47271523883157
# Episode: 32, Total Reward: -261.0773365433896
# Episode: 33, Total Reward: -231.93227165789483
# Episode: 34, Total Reward: -296.71938927799374
# Episode: 35, Total Reward: -147.00164476661288
# Episode: 36, Total Reward: -188.108504449669
# Episode: 37, Total Reward: -17.387394193664903
# Episode: 38, Total Reward: -95.61282775546026
# Episode: 39, Total Reward: -2.289461544505997
# Episode: 40, Total Reward: -138.84058244943273
# Episode: 41, Total Reward: -218.00311999041583
# Episode: 42, Total Reward: -127.58302427734029
# Episode: 43, Total Reward: 193.7332219294786
# Episode: 44, Total Reward: -80.58576850945252
# Episode: 45, Total Reward: -204.2108792203317
# Episode: 46, Total Reward: -197.84503813718294
# Episode: 47, Total Reward: -36.88208463685785
# Episode: 48, Total Reward: -44.29580332480653
# Episode: 49, Total Reward: -114.16305782236864
# Episode: 50, Total Reward: -47.51202504982605
# Episode: 51, Total Reward: -235.20955361785704
# Episode: 52, Total Reward: -274.99534413037145
# Episode: 53, Total Reward: 132.59458658136305
# Episode: 54, Total Reward: -25.918697357919896
# Episode: 55, Total Reward: -197.2292399414843
# Episode: 56, Total Reward: -94.07906054120863
# Episode: 57, Total Reward: -227.58069315045398
# Episode: 58, Total Reward: -145.6741880267854
# Episode: 59, Total Reward: 227.04740458194487
# Episode: 60, Total Reward: 223.124134394972
# Episode: 61, Total Reward: 3.950467017870295
# Episode: 62, Total Reward: 239.91277298766323
# Episode: 63, Total Reward: -37.45237609296066
# Episode: 64, Total Reward: -46.94280124998776
# Episode: 65, Total Reward: 208.05044929677928
# Episode: 66, Total Reward: -180.9237407623811
# Episode: 67, Total Reward: -3.217087634231092
# Episode: 68, Total Reward: -65.59925566157335
# Episode: 69, Total Reward: 17.608600943153803
# Episode: 70, Total Reward: -112.1187980395215
# Episode: 71, Total Reward: 177.95807618629988
# Episode: 72, Total Reward: -79.69098151946702
# Episode: 73, Total Reward: -54.21264706677425
# Episode: 74, Total Reward: -85.10992187722533
# Episode: 75, Total Reward: 113.34214876503871
# Episode: 76, Total Reward: -21.561987300872445
# Episode: 77, Total Reward: -52.46182181521404
# Episode: 78, Total Reward: -163.7141281336731
# Episode: 79, Total Reward: 175.44792856161354
# Episode: 80, Total Reward: -101.65347024480754
# Episode: 81, Total Reward: 194.1408624998478
# Episode: 82, Total Reward: -233.87019464760817
# Episode: 83, Total Reward: -105.2684776674037
# Episode: 84, Total Reward: -78.6109850724302
# Episode: 85, Total Reward: -208.6087596058424
# Episode: 86, Total Reward: -79.57872849116741
# Episode: 87, Total Reward: 172.9837541969111
# Episode: 88, Total Reward: -54.310639008740154
# Episode: 89, Total Reward: -192.8975532259934
# Episode: 90, Total Reward: -222.82476370357494
# Episode: 91, Total Reward: -20.902054780430817
# Episode: 92, Total Reward: -219.4663758560282
# Episode: 93, Total Reward: -289.61300505734175
# Episode: 94, Total Reward: -230.03255879143092
# Episode: 95, Total Reward: -160.30434051426218
# Episode: 96, Total Reward: -261.4458974838857
# Episode: 97, Total Reward: -18.895408113316066
# Episode: 98, Total Reward: -51.67375421495389
# Episode: 99, Total Reward: -254.82070988458327
# Episode: 100, Total Reward: -199.13865643827006
# Episode: 101, Total Reward: 26.684758788537636
# Episode: 102, Total Reward: -79.33804469999674
# Episode: 103, Total Reward: 2.0719044605390167
# Episode: 104, Total Reward: 188.89883476585015
# Episode: 105, Total Reward: 227.67615248592332
# Episode: 106, Total Reward: -198.14553825400236
# Episode: 107, Total Reward: -81.6454368199381
# Episode: 108, Total Reward: 186.0260590662057
# Episode: 109, Total Reward: -8.763963517492456
# Episode: 110, Total Reward: -29.571849471145057
# Episode: 111, Total Reward: -186.11798549091998
# Episode: 112, Total Reward: 91.70465515914988
# Episode: 113, Total Reward: 30.955901812920047
# Episode: 114, Total Reward: 160.98514824736637
# Episode: 115, Total Reward: 213.7212701274693
# Episode: 116, Total Reward: 240.1125793076102
# Episode: 117, Total Reward: -191.40452390056737
# Episode: 118, Total Reward: -201.42376358156577
# Episode: 119, Total Reward: 159.94188627861416
# Episode: 120, Total Reward: 243.38877573682913
# Episode: 121, Total Reward: -158.31501688221556
# Episode: 122, Total Reward: 208.02068755292973
# Episode: 123, Total Reward: -187.24204510615107
# Episode: 124, Total Reward: 19.835693864753452
# Episode: 125, Total Reward: 215.93690182375298
# Episode: 126, Total Reward: 255.47241429221174
# Episode: 127, Total Reward: -59.66643415618401
# Episode: 128, Total Reward: -34.4788341706481
# Episode: 129, Total Reward: -37.76668191386577
# Episode: 130, Total Reward: -27.520340696609935
# Episode: 131, Total Reward: -32.34326527126572
# Episode: 132, Total Reward: 220.63359729036898
# Episode: 133, Total Reward: -26.829680865685745
# Episode: 134, Total Reward: -196.986545798149
# Episode: 135, Total Reward: 273.5897574165902
# Episode: 136, Total Reward: -62.01531028699152
# Episode: 137, Total Reward: -38.32580782751002
# Episode: 138, Total Reward: -40.970793176628135
# Episode: 139, Total Reward: -50.5681638091523
# Episode: 140, Total Reward: -42.5475855826796
# Episode: 141, Total Reward: -173.11933706008034
# Episode: 142, Total Reward: -208.1423599460286
# Episode: 143, Total Reward: 187.81569421957514
# Episode: 144, Total Reward: -61.77654851402332
# Episode: 145, Total Reward: 189.41973114852306
# Episode: 146, Total Reward: -17.639381739882225
# Episode: 147, Total Reward: 120.20226163672197
# Episode: 148, Total Reward: -223.31227198973008
# Episode: 149, Total Reward: 10.989779306625096
# Episode: 150, Total Reward: 229.0243323927234
# Episode: 151, Total Reward: -185.29358810883525
# Episode: 152, Total Reward: 33.769283409970456
# Episode: 153, Total Reward: -91.46330560306187
# Episode: 154, Total Reward: -29.947923401310362
# Episode: 155, Total Reward: 12.6262988514233
# Episode: 156, Total Reward: -53.93486089655548
# Episode: 157, Total Reward: 214.66744931526327
# Episode: 158, Total Reward: 188.15871304504986
# Episode: 159, Total Reward: -279.32126144643576
# Episode: 160, Total Reward: 123.9153155609661
# Episode: 161, Total Reward: 192.60804800720328
# Episode: 162, Total Reward: -53.90499465229695
# Episode: 163, Total Reward: -9.588531560481215
# Episode: 164, Total Reward: -205.47796596487325
# Episode: 165, Total Reward: -68.55148659386123
# Episode: 166, Total Reward: -81.1821339003363
# Episode: 167, Total Reward: -42.78242199369633
# Episode: 168, Total Reward: 143.30224981257885
# Episode: 169, Total Reward: -150.92297164504367
# Episode: 170, Total Reward: -14.558932847628412
# Episode: 171, Total Reward: -39.82848779179528
# Episode: 172, Total Reward: -53.05120865946096
# Episode: 173, Total Reward: -186.7657694245762
# Episode: 174, Total Reward: -204.16613128213126
# Episode: 175, Total Reward: -22.42819233841884
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 14
#      12 next_state, reward, terminated, truncated, _ = env.step(action)
#      13 done = terminated or truncated
# ---> 14 agent.train_step(state, action, reward, next_state, done)
#      16 total_reward += reward
#      17 state = next_state
#
# Cell In[37], line 71, in ActorCriticAgent.train_step(self, state, action, reward, next_state, done)
#      68 actor_loss = -log_prob * advantage.detach()
#      70 self.actor_optimizer.zero_grad()
# ---> 71 actor_loss.backward()
#      72 self.actor_optimizer.step()
#
# File ~/anaconda3/envs/torch/lib/python3.12/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/anaconda3/envs/torch/lib/python3.12/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/anaconda3/envs/torch/lib/python3.12/site-packages/torch/autograd/graph.py:768, in _engine_run_backward(t_outputs, *args, **kwargs)
#     766     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     767 try:
# --> 768     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     769         t_outputs, *args, **kwargs
#     770     )  # Calls into the C++ engine to run the backward pass
#     771 finally:
#     772     if attach_logging_hooks:
#
# KeyboardInterrupt:
